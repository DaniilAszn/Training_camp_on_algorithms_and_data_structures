# %% [markdown]
# # **Спринт 2.2. Матрицы**

# %% [markdown]
# ## 2.2.1. [766. Toeplitz Matrix](https://leetcode.com/problems/toeplitz-matrix/description/)
#
# 1

# %%
class Solution:
    def isToeplitzMatrix(self, matrix: List[List[int]]) -> bool:
        m = len(matrix)
        n = len(matrix[0])

        for i in range(m - 1):
            for j in range(n - 1):
                if matrix[i][j] != matrix[i + 1][j + 1]:
                    return False

        return True

# %% [markdown]
# ## 2.2.2. [1572. Matrix Diagonal Sum](https://leetcode.com/problems/matrix-diagonal-sum/description/)
#
# 2

# %%
class Solution:
    def diagonalSum(self, mat: List[List[int]]) -> int:
        n = len(mat)
        ans = 0
        c_left = 0
        c_right = n - 1

        for r in range(n):
            ans += mat[r][c_left] + mat[r][c_right] * (c_left != c_right)
            c_left += 1
            c_right -= 1

        return ans

# %% [markdown]
# ## 2.2.3. [867. Transpose Matrix](https://leetcode.com/problems/transpose-matrix/description/)
#
# 2

# %%
class Solution:
    def transpose(self, matrix: List[List[int]]) -> List[List[int]]:
        m = len(matrix)
        n = len(matrix[0])
        ans = []

        for r in range(n):
            sub_ans = []
            for c in range(m):
                sub_ans.append(matrix[c][r])
            ans.append(sub_ans)

        return ans

# %% [markdown]
# # **Челлендж**

# %% [markdown]
# ## [3033. Modify the Matrix](https://leetcode.com/problems/modify-the-matrix/description/)
#
# 2

# %%
class Solution:
    def modifiedMatrix(self, matrix: List[List[int]]) -> List[List[int]]:
        m = len(matrix)
        n = len(matrix[0])

        for c in range(n):
            max_num_col = -2
            idxs_nums_to_replace = []
            for r in range(m):
                max_num_col = max(max_num_col, matrix[r][c])
                if matrix[r][c] == -1:
                    idxs_nums_to_replace.append(r)
            for r in idxs_nums_to_replace:
                matrix[r][c] = max_num_col

        return matrix

# %% [markdown]
# ## [2643. Row With Maximum Ones](https://leetcode.com/problems/row-with-maximum-ones/description/)
#
# 2

# %%
class Solution:
    def rowAndMaximumOnes(self, mat: List[List[int]]) -> List[int]:
        m = len(mat)
        n = len(mat[0])
        ans = [0, 0]

        for r in range(m):
            cnt_ones_row = 0
            max_cnt_ones_row = 0
            for c in range(n):
                cnt_ones_row += (mat[r][c] == 1)
                max_cnt_ones_row = max(max_cnt_ones_row, cnt_ones_row)
            if max_cnt_ones_row > ans[1]:
                ans[0], ans[1] = r, max_cnt_ones_row

        return ans
